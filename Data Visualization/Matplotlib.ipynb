# %% [markdown]
# # Why to visualize data?
# - Data visualization is a practice of translating information into a visual context,such as map or gragh,to make data easier for the human brain to understand and pull insights frrom.The main gaol of data visualization is to make it easier to identify pattern,trends and outlieers in the large data set.
# - Better analysis.
# - Quick action
# - identifying pattern
# - Finding error
# - Understsnding the story
# - Exporing the business insights
# - Graspping the latest trend.

# %% [markdown]
# # What is Matplotlib?
# - Matplotlib is a python visualization library,majorly use for plotting 2D data.
# - Matplotlib is a multi-platform data visualization library built on Numpy arrays and designed to work with the broder Scipy stack.
# - Matplotlib consist of several plots like line,bar,scatter,histogram etc.

# %%
#import neccessary libraries

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('cars.csv')

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
#installing Matplotlib


# !pip install Matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
#import library
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %% [markdown]
# # Matplotlib line plot

# %%
x= np.linspace(1,10,15)
y=[1,2,65,4,21,25,36,12,45,89,6,95,56,45,85]
plt.plot(x,y)
#plt.show()

# %%
#Change the size of the ghaph

plt.rcParams['figure.figsize']=(10,5)
plt.rcParams['figure.dpi']=150

# %%
plt.plot(x,y,'g--')

# %%
a=np.random.randint(1,10,25)
plt.plot(a,'b',linewidth=5,linestyle='--')

# %%
x=np.array([1,2,3,4,])
y=x*2
y

plt.plot(x,y,'r--')

# %%
x=np.array([1,2,3,4,])
y=x*2

plt.plot(x,y,'r--')

x1=[2,4,6,8]
y1=[3,5,7,9]
 
plt.plot(x1,y1)

plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('X vs Y line graph')
# Out:
# Text(0.5, 1.0, 'X vs Y line graph')

# %%
x=[1,2,3,4,5]
y=[-2,4,6,8,10]
plt.plot(x,y)
plt.grid()

# %%
x=[1,2,3,4,5]
y=[-2,4,6,8,10]
plt.plot(x,y)
plt.grid(color='green',linewidth=0.5,linestyle='--')

# %% [markdown]
# - xlim:used to deffine limit foe x variables
# - ylim:used to define limit for y variables

# %%
area=[1000,1520,2000,3000,5210]
price=[10,15,12,25,30]
plt.plot(area,price)
plt.grid()
plt.xlim(1000,6000)
plt.ylim(5,50)
plt.xlabel('Area of the house')
plt.ylabel('Price tof the house')
# Out:
# Text(0, 0.5, 'Price tof the house')

# %% [markdown]
# # Matplotlib Histogram
# - A histoghram is a graph showing frequency distribution.
# - it is a graph showing number of obeservation in each given interval.

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns',None)

# %%
df=pd.read_csv('Automobile_data.csv')
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %%
df.shape[0]
# Out:
# 205

# %%
df.shape
# Out:
# (205, 26)

# %%
df.describe().T
# Out:
#                    count         mean         std     min     25%     50%  \
# symboling          205.0     0.834146    1.245307    -2.0     0.0     1.0
# wheel-base         205.0    98.756585    6.021776    86.6    94.5    97.0
# length             205.0   174.049268   12.337289   141.1   166.3   173.2
# width              205.0    65.907805    2.145204    60.3    64.1    65.5
# height             205.0    53.724878    2.443522    47.8    52.0    54.1
# curb-weight        205.0  2555.565854  520.680204  1488.0  2145.0  2414.0
# engine-size        205.0   126.907317   41.642693    61.0    97.0   120.0
# compression-ratio  205.0    10.142537    3.972040     7.0     8.6     9.0
# city-mpg           205.0    25.219512    6.542142    13.0    19.0    24.0
# highway-mpg        205.0    30.751220    6.886443    16.0    25.0    30.0
#
#                       75%     max
# symboling             2.0     3.0
# wheel-base          102.4   120.9
# length              183.1   208.1
# ...

# %%
df.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
plt.hist(df['width'])
plt.title('Width frequency table')
plt.xlabel('Width')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
width_mean=df['width'].mean()
width_median=df['width'].median()

df['width'].hist(bins=10)
plt.axvline(width_mean,color='y')
plt.axvline(width_median,color='r')
plt.ylabel('Frequency')
plt.xlabel('Width')
# Out:
# Text(0.5, 0, 'Width')

# %% [markdown]
# # Seaborn

# %% [markdown]
# COUNTPLOT

# %%
import seaborn as sns
sns.countplot(df['body-style'])
# Out:
# <AxesSubplot:xlabel='body-style', ylabel='count'>

# %%
df['body-style'].value_counts()
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: body-style, dtype: int64

# %%
df['make'].nunique()
# Out:
# 22

# %%
#set theme and style for graph
 
sns.set_theme(style='darkgrid',palette='rainbow')

# %%
sns.countplot(y='make',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='make'>

# %%
sns.countplot(data=df,x='body-style',hue="fuel-type")
# Out:
# <AxesSubplot:xlabel='body-style', ylabel='count'>

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %%
#distribution plots

# %%
sns.histplot(df['curb-weight'])
# Out:
# <AxesSubplot:xlabel='curb-weight', ylabel='Count'>

# %%
sns.displot(df['curb-weight'])

# %%
sns.kdeplot(df['curb-weight'])
# Out:
# <AxesSubplot:xlabel='curb-weight', ylabel='Density'>
