# %% [markdown]
# # Paandas
# 1.pandas is an open soure library,that is mainly made for working with rational or labled data both easily and intuitively.
#
#
#
# 2.It provides various data structures and operators for manipulating numerical data and time series.
#
#
# 3.This library is built on top of Numpy library.
#
#
# 4.Pandas is fast and it has high performanace and productivity for users.
#
# 5.Pandas generally provides two data structures for manipulating data,they are
# - series
# - dataframe

# %%
import pandas as pd

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %% [markdown]
# # Series
# Series is one dimensional lebaled arrey and capable of holding  data of any type (float,integer,strind,python object etc)

# %%
#Series creation

# %%
lst=[1,2,3,4]
type(lst)
# Out:
# list

# %%
s = pd.Series(lst)
type(s)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s=pd.Series(data=[10,20,30],index=['A','B','C'],name='My_Series')
s
# Out:
# A    10
# B    20
# C    30
# Name: My_Series, dtype: int64

# %%
#Accessing element from a series using index labels

# %%
s[0]
# Out:
# 10

# %%
s['C']
# Out:
# 30

# %%
s[0:1]
# Out:
# A    10
# Name: My_Series, dtype: int64

# %% [markdown]
# # Dataframe
# - it is 2 dimensional data structure

# %% [markdown]
# # Why to create pandas dataframe
# - by creating nested list and colname list
# - by creating a dictionary

# %%
lst=[['Python',90,'Pune'],['ML',100,'Mumbai'],['DL',95,'HYD']]

col=['Subject','Marks','City']

# %%
df=pd.DataFrame(data=lst,columns=col)

# %%
df
# Out:
#   Subject  Marks    City
# 0  Python     90    Pune
# 1      ML    100  Mumbai
# 2      DL     95     HYD

# %%
#Cheack number of rows and columns in dataframe

# %%
df.shape
# Out:
# (3, 3)

# %%
df.ndim
# Out:
# 2

# %%
df.dtypes
# Out:
# Subject    object
# Marks       int64
# City       object
# dtype: object

# %%
df.Subject
# Out:
# 0    Python
# 1        ML
# 2        DL
# Name: Subject, dtype: object

# %%
df['Subject']
# Out:
# 0    Python
# 1        ML
# 2        DL
# Name: Subject, dtype: object

# %%
df
# Out:
#   Subject  Marks    City
# 0  Python     90    Pune
# 1      ML    100  Mumbai
# 2      DL     95     HYD

# %%
df[['Subject']]
# Out:
#   Subject
# 0  Python
# 1      ML
# 2      DL

# %%
#discreptive stat for df

# %%
df.describe()
# Out:
#        Marks
# count    3.0
# mean    95.0
# std      5.0
# min     90.0
# 25%     92.5
# 50%     95.0
# 75%     97.5
# max    100.0

# %%
df.describe(include='O')
# Out:
#        Subject  City
# count        3     3
# unique       3     3
# top     Python  Pune
# freq         1     1

# %%
df.describe(include='all')
# Out:
#        Subject  Marks  City
# count        3    3.0     3
# unique       3    NaN     3
# top     Python    NaN  Pune
# freq         1    NaN     1
# mean       NaN   95.0   NaN
# std        NaN    5.0   NaN
# min        NaN   90.0   NaN
# 25%        NaN   92.5   NaN
# 50%        NaN   95.0   NaN
# 75%        NaN   97.5   NaN
# max        NaN  100.0   NaN

# %%
#Gettting information about dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Subject  3 non-null      object
#  1   Marks    3 non-null      int64
#  2   City     3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 200.0+ bytes

# %%
#Cheacking null values

# %%
df.isnull()
# Out:
#    Subject  Marks   City
# 0    False  False  False
# 1    False  False  False
# 2    False  False  False

# %% [markdown]
# # Importing external datasets

# %%
#load the csv files

# %%
df=pd.read_csv(r'C:\Users\Gau\Desktop\DS1\Salaries.csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
#Reading first 5 records

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
#Reading last 5 records

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
#Reading all records

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
pd.set_option('display.max_columns',None)

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
#Describe the data

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.describe(include='all')
# Out:
#         rank discipline        phd    service   sex         salary
# count     78         78  78.000000  78.000000    78      78.000000
# unique     3          2        NaN        NaN     2            NaN
# top     Prof          B        NaN        NaN  Male            NaN
# freq      46         42        NaN        NaN    39            NaN
# mean     NaN        NaN  19.705128  15.051282   NaN  108023.782051
# std      NaN        NaN  12.498425  12.139768   NaN   28293.661022
# min      NaN        NaN   1.000000   0.000000   NaN   57800.000000
# 25%      NaN        NaN  10.250000   5.250000   NaN   88612.500000
# 50%      NaN        NaN  18.500000  14.500000   NaN  104671.000000
# 75%      NaN        NaN  27.750000  20.750000   NaN  126774.750000
# max      NaN        NaN  56.000000  51.000000   NaN  186960.000000

# %%
#Extracting only columns

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
#Selecting single nd multiple columns

# %%
df.phd
# Out:
# 0     56
# 1     12
# 2     23
# 3     40
# 4     20
# 5     20
# 6     20
# 7     18
# 8     29
# 9     51
# 10    39
# 11    23
# 12     1
# 13    35
# 14    25
# 15    17
# 16     8
# 17     4
# 18    19
# 19    29
# 20     4
# 21    33
# 22     4
# 23     2
# 24    30
# 25    35
# 26    38
# 27    45
# 28     7
# 29    21
# 30     9
# 31    22
# 32    27
# 33    18
# 34    12
# 35    28
# 36    45
# 37    20
# 38     4
# 39    18
# 40    39
# 41    13
# 42     4
# 43     5
# 44    23
# 45    25
# 46    11
# 47    11
# 48    17
# 49    17
# 50    10
# 51    20
# 52    12
# 53     5
# 54    25
# 55     2
# 56    10
# 57     3
# 58    36
# 59    12
# 60     3
# 61    13
# 62    14
# 63    29
# 64    26
# 65    36
# 66     7
# 67    17
# 68     4
# 69    28
# 70     8
# 71    12
# 72    24
# 73    18
# 74    19
# 75    17
# 76    28
# 77    23
# Name: phd, dtype: int64

# %%
df[['phd','salary']]
# Out:
#     phd  salary
# 0    56  186960
# 1    12   93000
# 2    23  110515
# 3    40  131205
# 4    20  104800
# 5    20  122400
# 6    20   81285
# 7    18  126300
# 8    29   94350
# 9    51   57800
# 10   39  128250
# 11   23  134778
# 12    1   88000
# 13   35  162200
# 14   25  153750
# 15   17  150480
# 16    8   75044
# 17    4   92000
# 18   19  107300
# 19   29  150500
# 20    4   92000
# 21   33  103106
# 22    4   73000
# 23    2   85000
# 24   30   91100
# 25   35   99418
# 26   38  148750
# 27   45  155865
# 28    7   91300
# 29   21  123683
# 30    9  107008
# 31   22  155750
# 32   27  103275
# 33   18  120000
# 34   12  119800
# 35   28  126933
# 36   45  146856
# 37   20  102000
# 38    4   91000
# 39   18  129000
# 40   39  137000
# 41   13   74830
# 42    4   80225
# 43    5   77000
# 44   23  151768
# 45   25  140096
# 46   11   74692
# 47   11  103613
# 48   17  111512
# 49   17  122960
# 50   10   97032
# 51   20  127512
# 52   12  105000
# 53    5   73500
# ...

# %%
#Selecting columns with loc and iloc

# %%
#loc function

# %%
df.loc[10:15,'phd']
# Out:
# 10    39
# 11    23
# 12     1
# 13    35
# 14    25
# 15    17
# Name: phd, dtype: int64

# %%
df.loc[10:15,'phd':'salary']
# Out:
#     phd  service   sex  salary
# 10   39       33  Male  128250
# 11   23       23  Male  134778
# 12    1        0  Male   88000
# 13   35       33  Male  162200
# 14   25       19  Male  153750
# 15   17        3  Male  150480

# %%
df.head(2)
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000

# %%
df.iloc[50:56,1]
# Out:
# 50    B
# 51    B
# 52    A
# 53    A
# 54    A
# 55    A
# Name: discipline, dtype: object

# %%
df.iloc[50:56,0:3]
# Out:
#          rank discipline  phd
# 50   AsstProf          B   10
# 51       Prof          B   20
# 52       Prof          A   12
# 53   AsstProf          A    5
# 54  AssocProf          A   25
# 55   AsstProf          A    2

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
#value count

# %%
df['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
df['discipline'].value_counts()
# Out:
# B    42
# A    36
# Name: discipline, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# Male      39
# Female    39
# Name: sex, dtype: int64

# %%
#Renameing column name

# %%
df.rename(columns={'rank':'Rank'})
# Out:
#          Rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.rename(columns={'discipline':'Discipline','phd':'PHD'},inplace=True)

# %%
df
# Out:
#          rank Discipline  PHD  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...
